# %% [markdown]
# **to plot anything that you'd like from this data**.  produce **two plots**. High-level principals are those figures should be clear to understand/digest, effective and simple.
#
# making a type of plot you've never made before -- perhaps never even seen before! Give a brief explanation of the reason and usefulness of the plot.
#
# Your data is the <a href="https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_boston.html#sklearn.datasets.load_boston" target="_blank">Boston housing prices dataset</a>. It will be loaded directly from sklearn
#
# **References**:
# 1. for tons of great examples, visit the <a href="https://matplotlib.org/gallery/index.html" target="_blank">matplotlib</a> website.
#
# 2. [How to Think about Data Visualization](https://www.youtube.com/watch?v=vTingdk_pVM)
#
# 3. [Best Data Visualization Projects of 2020](https://flowingdata.com/2020/12/23/best-data-visualization-projects-of-2020/)
#
# 4. [PyViz Tutorials](https://pyviz.org/tutorials/index.html)

# %%
import pandas as pd
import numpy as np

data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
target = raw_df.values[1::2, 2]

# Now you can use 'data' as your feature matrix and 'target' as your target variable
# For example, print the shape of the data and target
print("Data shape:", data.shape)
print("Target shape:", target.shape)
# Out:
# Data shape: (506, 13)
# Target shape: (506,)

# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd

# Load the California housing dataset
housing = fetch_california_housing()

# The dataset is a dictionary-like object
# You can access data, target, feature names, and other information
data = pd.DataFrame(data=housing.data, columns=housing.feature_names)
target = pd.Series(data=housing.target, name="target")

# Display the first few rows of the dataset
print("Head of the data:")
print(data.head())

# Display information about the dataset
print("\nInformation about the dataset:")
print(data.info())

# Display summary statistics of the dataset
print("\nSummary statistics of the dataset:")
print(data.describe())

# Display the target variable
print("\nTarget variable:")
print(target.head())
# Out:
# Head of the data:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25
#
# Information about the dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
# ...

# %%
# our boring example
plt.figure(figsize=(5, 4))
plt.hist(boston.target)
plt.title('Boston Housing Prices')
plt.xlabel('Price ($1000)')
plt.ylabel('# of Houses')
plt.show()

# %%
import matplotlib.pyplot as plt

# Scatter plot of a couple of features against the target variable
plt.figure(figsize=(12, 6))

# Example: Scatter plot of 'MedInc' (median income) against the target variable
plt.scatter(data['MedInc'], target, alpha=0.5)
plt.title('Scatter Plot of Median Income vs. Housing Price')
plt.xlabel('Median Income')
plt.ylabel('Housing Price')

plt.show()

# %%
import matplotlib.pyplot as plt

# Plot a bar plot of housing prices
plt.figure(figsize=(12, 6))
plt.bar(target.unique(), target.value_counts().sort_index())
plt.title('Number of Houses at Each Housing Price')
plt.xlabel('Housing Price')
plt.ylabel('Number of Houses')
plt.show()

# %%
#EDA

# %%
boston_pd.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
boston_pd.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# dtype: int64

# %%
import seaborn as sns 

# %matplotlib inline

# %%
boston_pd['MEDV'] = boston.target

# MEDV: Median value of owner-occupied homes in $1000s

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(boston_pd['MEDV'], bins=30)
plt.show()
# Out:
# C:\Users\isaac.sadikin\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# the values of MEDV are distributed normally with few outliers

# %%
correlation_matrix = boston_pd.corr().round(2)
# annot = True to print the values inside the square
sns.heatmap(data=correlation_matrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
# The correlation coefficient ranges from -1 to 1. 
# If the value is close to 1, 
# it means that there is a strong positive correlation between the two variables. 
# When it is close to -1, the variables have a strong negative correlation

# %%
#Your First Plot

# Plot no 1


plt.figure(figsize=(20, 5))

features = ['INDUS', 'TAX','DIS']
target = boston_pd['NOX']

for i, col in enumerate(features):
    plt.subplot(1, len(features) , i+1)
    x = boston_pd[col]
    y = target
    plt.scatter(x, y, marker='o')
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('NOX')

# %%
# Explanation for plot no 1
# 1a - NOX vs INDUS : there is positive correlation between the concentration of NOX and 
# The proportion of non-retail business acres per town.
# From correlation_matrix, it was indicated the positive correlation was 0.76
# It is clearly that the more the number of the Proportion of non-retail business acres per town, 
# it will produce more NOX pollution in that area as it is denser of numbers of factories. 
# It can be an indication whether the areas are healthy or not with the indication of higher concentration of NOX and 
# it is a crucial information for goverment / local authority to impose any clean up air pollution by respective 
# factories in the area.

# 1b - NOX vs TAX : there is positive correlation between the concentration of NOX and 
# full-value property tax rate per $10,000.
# From correlation_matrix, it was indicated the positive correlation was 0.67
# It is clearly that the higher of the Full-value property tax rate per $10,000, 
# it will produce more NOX pollution in that area as the factories have bigger areas  
# hence, it has higher property tax rate.
# It can be an indication whether the areas are healthy or not with the indication of higher concentration of NOX and 
# it is a crucial information for goverment / local authority to impose any clean up air pollution by respective 
# factories in the area.


# 1c - NOX vs DIS : there is negative correlation between the concentration of NOX and
# Weighted distances to five Boston employment centers
# from correlation_matrix, it was indicated the negative correlation was -0.77
# it is clearly that the higher Weighted distances to five Boston employment centers, 
# it will produce lesser NOX pollution in that area as the factories are getting lesser with higher distances  
# it can be an indication whether the areas are healthy or not with the indication of higher concentration of NOX and 
# it is a crucial information for goverment / local authority to impose any clean up air pollution by respective 
# factories in the area

# %%
#Your Second Plot

# Plot no 2

# %%
from bokeh.io import output_notebook, show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.plotting import figure, show, ColumnDataSource

# %%
tools ="pan,hover,box_select,lasso_select,wheel_zoom,box_zoom,reset"
source = ColumnDataSource(data=dict(
    x=boston_pd.CRIM,
    y1=boston_pd.RAD,
    y2=boston_pd.TAX,
    y3=boston_pd.DIS,
))

p4 = figure(plot_width=250, plot_height=240, title="RAD vs CRIM", tools=tools)
p4.circle(x='x', y='y1', source=source, alpha=0.4, color='darkred')
p5 = figure(plot_width=250, plot_height=240, title="TAX vs CRIM", tools=tools, x_range=p4.x_range)
p5.circle(x='x', y='y2', source=source, alpha=0.4, color='darkgreen')
p6 = figure(plot_width=250, plot_height=240, title="DIS vs CRIM", tools=tools, x_range=p4.x_range)
p6.circle(x='x', y='y3', source=source, alpha=0.4, color='darkblue')
p44 = gridplot([[p4, p5, p6]])
p4.xaxis.axis_label = "Criminal (Per capita crime rate by town)"
p5.xaxis.axis_label = "Criminal (Per capita crime rate by town)"
p6.xaxis.axis_label = "Criminal (Per capita crime rate by town)"
show(p44)
# Out:
#   <div class="bk-root" id="6edec89f-ac46-446f-a0ac-71d2fab55765" data-root-id="2347"></div>

# %%
# Explanation for plot no 2
# 2a - RAD vs CRIM : there is positive correlation between the Index of accessibility to radial highways and 
# the Per capita crime rate by town.
# From correlation_matrix, it was indicated the positive correlation was 0.63
# It is clearly that the more the number of the Index of accessibility to radial highways, 
# it will produce more Per capita crime rate by town in that area as it is easier to escape to any highways 
# in the fastest fashion. 
# It can be an indication whether the areas are safe or not safe with the indication of higher crime and 
# it is a crucial information for goverment / local authority to impose any increase number of security  
# officers / police officers in the area.

# 2b - TAX vs CRIM : there is positive correlation between the Full-value property tax rate per $10,000 and 
# the Per capita crime rate by town.
# From correlation_matrix, it was indicated the positive correlation was 0.58
# It is clearly that the higher of the Full-value property tax rate per $10,000, 
# it will produce more Per capita crime rate by town in that area as the criminals target these people who stay in this area.  
# It can be an indication whether the areas are safe or not safe with the indication of higher crime and 
# it is a crucial information for goverment / local authority to impose any increase number of security  
# officers / police officers in the area.


# 2c - DIS vs CRIM : there is negative correlation between the Weighted distances to five Boston employment centers and
# the Per capita crime rate by town
# from correlation_matrix, it was indicated the negative correlation was -0.38
# It is clearly that the higher Weighted distances to five Boston employment centers, 
# it will produce lesser Per capita crime rate by town in that area as the 
# number of employment centers are getting lesser in that area.
# It can be an indication whether the areas are safe or not safe with the indication of higher crime and 
# it is a crucial information for goverment / local authority to impose any increase number of security  
# officers / police officers in the area.
